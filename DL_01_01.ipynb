# %%
import numpy as np

# %reload_ext version_information

np.__version__
# Out:
# '1.16.4'

# %%
# %version_information numpy
# Out:
# Software versions
# Python 3.7.3 64bit [MSC v.1915 64 bit (AMD64)]
# IPython 7.6.1
# OS Windows 10 10.0.18362 SP0
# numpy 1.16.4
# Mon Dec 02 07:32:01 2019 Mitteleuropäische Zeit
